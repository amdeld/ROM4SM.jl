# %%
import numpy as np
from numpy import linalg 
from matplotlib import cm
from matplotlib import pyplot as plt

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %%
# Define data
x = np.linspace(-2,2,401) # spatial coordinate
Nx = np.size(x)

amp1 = 1
x01 = 0.5
sigmay1 = 0.6

amp2 = 1.2
x02 = -0.5
sigmay2 = 0.3

dt = 0.01
Nt = 1001
tend = dt*(Nt-1)
t = np.linspace(0,tend,Nt) # time

omega1 = 1.3
omega2 = 4.1

# %%
Nx,Nt
# Out:
# (401, 1001)

# %%
y1 = amp1*np.exp(-((x-x01)**2)/(2*sigmay1**2))
y2 = amp2*np.exp(-((x-x02)**2)/(2*sigmay2**2))

Y = np.zeros([Nx,Nt],dtype='d')

# %%
for tt in range(Nt):
    Y[:,tt] = y1*np.sin(2*np.pi*omega1*t[tt]) + y2*np.sin(2*np.pi*omega2*t[tt])

# %%
print(np.shape(Y))
# Out:
# (401, 1001)

# %%
Y
# Out:
# array([[ 0.00000000e+00,  1.49980407e-05,  2.98284771e-05, ...,
#         -2.98284771e-05, -1.49980407e-05,  5.25832551e-19],
#        [ 0.00000000e+00,  1.61984741e-05,  3.22091245e-05, ...,
#         -3.22091245e-05, -1.61984741e-05,  5.48291007e-19],
#        [ 0.00000000e+00,  1.75012987e-05,  3.47917690e-05, ...,
#         -3.47917690e-05, -1.75012987e-05,  5.69605107e-19],
#        ...,
#        [ 0.00000000e+00,  3.89421446e-03,  7.76246173e-03, ...,
#         -7.76246173e-03, -3.89421446e-03,  1.87160762e-16],
#        [ 0.00000000e+00,  3.73684614e-03,  7.44877446e-03, ...,
#         -7.44877446e-03, -3.73684614e-03,  1.79597446e-16],
#        [ 0.00000000e+00,  3.58484128e-03,  7.14577833e-03, ...,
#         -7.14577833e-03, -3.58484128e-03,  1.72291905e-16]])

# %%
plt.plot(x,y1)
plt.plot(x,y2)
plt.xlabel('x', fontsize=18)
plt.ylabel('y1,y2', fontsize=18);

# %%
# Plot all data
Tgrid,Ygrid = np.meshgrid(t,x)

# %%
Tgrid
# Out:
# array([[ 0.  ,  0.01,  0.02, ...,  9.98,  9.99, 10.  ],
#        [ 0.  ,  0.01,  0.02, ...,  9.98,  9.99, 10.  ],
#        [ 0.  ,  0.01,  0.02, ...,  9.98,  9.99, 10.  ],
#        ...,
#        [ 0.  ,  0.01,  0.02, ...,  9.98,  9.99, 10.  ],
#        [ 0.  ,  0.01,  0.02, ...,  9.98,  9.99, 10.  ],
#        [ 0.  ,  0.01,  0.02, ...,  9.98,  9.99, 10.  ]])

# %%
print(np.shape(Tgrid))
# Out:
# (401, 1001)

# %%
print(np.shape(Ygrid))
# Out:
# (401, 1001)

# %%
Ygrid
# Out:
# array([[-2.  , -2.  , -2.  , ..., -2.  , -2.  , -2.  ],
#        [-1.99, -1.99, -1.99, ..., -1.99, -1.99, -1.99],
#        [-1.98, -1.98, -1.98, ..., -1.98, -1.98, -1.98],
#        ...,
#        [ 1.98,  1.98,  1.98, ...,  1.98,  1.98,  1.98],
#        [ 1.99,  1.99,  1.99, ...,  1.99,  1.99,  1.99],
#        [ 2.  ,  2.  ,  2.  , ...,  2.  ,  2.  ,  2.  ]])

# %%
plt.contour(Ygrid,Tgrid,np.abs(Y))
plt.colorbar()
plt.xlabel('x', fontsize=18)
plt.ylabel('time', fontsize=18)
plt.ylim(0, 2);

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(Ygrid,Tgrid,Y)
plt.show()

# %%
U,S,VT = linalg.svd(Y,full_matrices=False)
print(np.shape(U))
print(np.shape(S))
print(np.shape(VT))
# Out:
# (401, 401)
# (401,)
# (401, 1001)

# %%
S
# Out:
# array([2.46880682e+02, 1.74637349e+02, 2.22812742e-13, 2.07475096e-13,
#        2.00639008e-13, 1.85767294e-13, 1.66798125e-13, 1.47489770e-13,
#        1.40775730e-13, 1.26517637e-13, 1.03031359e-13, 9.49397897e-14,
#        6.59529331e-14, 5.36635338e-14, 5.35618038e-14, 4.40835025e-14,
#        3.65273137e-14, 2.31874878e-14, 2.31874878e-14, 2.31874878e-14,
#        2.31874878e-14, 2.31874878e-14, 2.31874878e-14, 2.31874878e-14,
#        2.31874878e-14, 2.31874878e-14, 2.31874878e-14, 2.31874878e-14,
#        2.31874878e-14, 2.31874878e-14, 2.31874878e-14, 2.31874878e-14,
#        2.31874878e-14, 2.31874878e-14, 2.31874878e-14, 2.31874878e-14,
#        2.31874878e-14, 2.31874878e-14, 2.31874878e-14, 2.31874878e-14,
#        2.31874878e-14, 2.31874878e-14, 2.31874878e-14, 2.31874878e-14,
#        2.31874878e-14, 2.31874878e-14, 2.31874878e-14, 2.31874878e-14,
#        2.31874878e-14, 2.31874878e-14, 2.31874878e-14, 2.31874878e-14,
#        2.31874878e-14, 2.31874878e-14, 2.31874878e-14, 2.31874878e-14,
#        2.31874878e-14, 2.31874878e-14, 2.31874878e-14, 2.31874878e-14,
#        2.31874878e-14, 2.31874878e-14, 2.31874878e-14, 2.31874878e-14,
#        2.31874878e-14, 2.31874878e-14, 2.31874878e-14, 2.31874878e-14,
#        2.31874878e-14, 2.31874878e-14, 2.31874878e-14, 2.31874878e-14,
#        2.31874878e-14, 2.31874878e-14, 2.31874878e-14, 2.31874878e-14,
#        2.31874878e-14, 2.31874878e-14, 2.31874878e-14, 2.31874878e-14,
#        2.31874878e-14, 2.31874878e-14, 2.31874878e-14, 2.31874878e-14,
#        2.31874878e-14, 2.31874878e-14, 2.31874878e-14, 2.31874878e-14,
#        2.31874878e-14, 2.31874878e-14, 2.31874878e-14, 2.31874878e-14,
#        2.31874878e-14, 2.31874878e-14, 2.31874878e-14, 2.31874878e-14,
#        2.31874878e-14, 2.31874878e-14, 2.31874878e-14, 2.31874878e-14,
#        2.31874878e-14, 2.31874878e-14, 2.31874878e-14, 2.31874878e-14,
#        2.31874878e-14, 2.31874878e-14, 2.31874878e-14, 2.31874878e-14,
#        2.31874878e-14, 2.31874878e-14, 2.31874878e-14, 2.31874878e-14,
#        2.31874878e-14, 2.31874878e-14, 2.31874878e-14, 2.31874878e-14,
#        2.31874878e-14, 2.31874878e-14, 2.31874878e-14, 2.31874878e-14,
#        2.31874878e-14, 2.31874878e-14, 2.31874878e-14, 2.31874878e-14,
#        2.31874878e-14, 2.31874878e-14, 2.31874878e-14, 2.31874878e-14,
#        2.31874878e-14, 2.31874878e-14, 2.31874878e-14, 2.31874878e-14,
#        2.31874878e-14, 2.31874878e-14, 2.31874878e-14, 2.31874878e-14,
#        2.31874878e-14, 2.31874878e-14, 2.31874878e-14, 2.31874878e-14,
#        2.31874878e-14, 2.31874878e-14, 2.31874878e-14, 2.31874878e-14,
#        2.31874878e-14, 2.31874878e-14, 2.31874878e-14, 2.31874878e-14,
#        2.31874878e-14, 2.31874878e-14, 2.31874878e-14, 2.31874878e-14,
#        2.31874878e-14, 2.31874878e-14, 2.31874878e-14, 2.31874878e-14,
#        2.31874878e-14, 2.31874878e-14, 2.31874878e-14, 2.31874878e-14,
#        2.31874878e-14, 2.31874878e-14, 2.31874878e-14, 2.31874878e-14,
#        2.31874878e-14, 2.31874878e-14, 2.31874878e-14, 2.31874878e-14,
#        2.31874878e-14, 2.31874878e-14, 2.31874878e-14, 2.31874878e-14,
#        2.31874878e-14, 2.31874878e-14, 2.31874878e-14, 2.31874878e-14,
#        2.31874878e-14, 2.31874878e-14, 2.31874878e-14, 2.31874878e-14,
#        2.31874878e-14, 2.31874878e-14, 2.31874878e-14, 2.31874878e-14,
#        2.31874878e-14, 2.31874878e-14, 2.31874878e-14, 2.31874878e-14,
#        2.31874878e-14, 2.31874878e-14, 2.31874878e-14, 2.31874878e-14,
#        2.31874878e-14, 2.31874878e-14, 2.31874878e-14, 2.31874878e-14,
#        2.31874878e-14, 2.31874878e-14, 2.31874878e-14, 2.31874878e-14,
#        2.31874878e-14, 2.31874878e-14, 2.31874878e-14, 2.31874878e-14,
#        2.31874878e-14, 2.31874878e-14, 2.31874878e-14, 2.31874878e-14,
#        2.31874878e-14, 2.31874878e-14, 2.31874878e-14, 2.31874878e-14,
#        2.31874878e-14, 2.31874878e-14, 2.31874878e-14, 2.31874878e-14,
#        2.31874878e-14, 2.31874878e-14, 2.31874878e-14, 2.31874878e-14,
#        2.31874878e-14, 2.31874878e-14, 2.31874878e-14, 2.31874878e-14,
#        2.31874878e-14, 2.31874878e-14, 2.31874878e-14, 2.31874878e-14,
#        2.31874878e-14, 2.31874878e-14, 2.31874878e-14, 2.31874878e-14,
#        2.31874878e-14, 2.31874878e-14, 2.31874878e-14, 2.31874878e-14,
#        2.31874878e-14, 2.31874878e-14, 2.31874878e-14, 2.31874878e-14,
#        2.31874878e-14, 2.31874878e-14, 2.31874878e-14, 2.31874878e-14,
#        2.31874878e-14, 2.31874878e-14, 2.31874878e-14, 2.31874878e-14,
#        2.31874878e-14, 2.31874878e-14, 2.31874878e-14, 2.31874878e-14,
#        2.31874878e-14, 2.31874878e-14, 2.31874878e-14, 2.31874878e-14,
#        2.31874878e-14, 2.31874878e-14, 2.31874878e-14, 2.31874878e-14,
#        2.31874878e-14, 2.31874878e-14, 2.31874878e-14, 2.31874878e-14,
#        2.31874878e-14, 2.31874878e-14, 2.31874878e-14, 2.31874878e-14,
#        2.31874878e-14, 2.31874878e-14, 2.31874878e-14, 2.31874878e-14,
#        2.31874878e-14, 2.31874878e-14, 2.31874878e-14, 2.31874878e-14,
#        2.31874878e-14, 2.31874878e-14, 2.31874878e-14, 2.31874878e-14,
#        2.31874878e-14, 2.31874878e-14, 2.31874878e-14, 2.31874878e-14,
#        2.31874878e-14, 2.31874878e-14, 2.31874878e-14, 2.31874878e-14,
#        2.31874878e-14, 2.31874878e-14, 2.31874878e-14, 2.31874878e-14,
#        2.31874878e-14, 2.31874878e-14, 2.31874878e-14, 2.31874878e-14,
#        2.31874878e-14, 2.31874878e-14, 2.31874878e-14, 2.31874878e-14,
#        2.31874878e-14, 2.31874878e-14, 2.31874878e-14, 2.31874878e-14,
#        2.31874878e-14, 2.31874878e-14, 2.31874878e-14, 2.31874878e-14,
#        2.31874878e-14, 2.31874878e-14, 2.31874878e-14, 2.31874878e-14,
#        2.31874878e-14, 2.31874878e-14, 2.31874878e-14, 2.31874878e-14,
#        2.31874878e-14, 2.31874878e-14, 2.31874878e-14, 2.31874878e-14,
#        2.31874878e-14, 2.31874878e-14, 2.31874878e-14, 2.31874878e-14,
#        2.31874878e-14, 2.31874878e-14, 2.31874878e-14, 2.31874878e-14,
#        2.31874878e-14, 2.31874878e-14, 2.31874878e-14, 2.31874878e-14,
#        2.31874878e-14, 2.31874878e-14, 2.31874878e-14, 2.31874878e-14,
#        2.31874878e-14, 2.31874878e-14, 2.31874878e-14, 2.31874878e-14,
#        2.31874878e-14, 2.31874878e-14, 2.31874878e-14, 2.31874878e-14,
#        2.31874878e-14, 2.31874878e-14, 2.31874878e-14, 2.31874878e-14,
#        2.31874878e-14, 2.31874878e-14, 2.31874878e-14, 2.31874878e-14,
#        2.31874878e-14, 2.31874878e-14, 2.31874878e-14, 2.31874878e-14,
#        2.31874878e-14, 2.31874878e-14, 2.31874878e-14, 2.31874878e-14,
#        2.31874878e-14, 2.31874878e-14, 2.31874878e-14, 2.31874878e-14,
#        2.31874878e-14, 2.31874878e-14, 2.31874878e-14, 2.31874878e-14,
#        2.31874878e-14, 2.31874878e-14, 2.31874878e-14, 2.31874878e-14,
#        2.31874878e-14, 2.31874878e-14, 2.31874878e-14, 2.31874878e-14,
#        2.31874878e-14, 2.31874878e-14, 2.31874878e-14, 2.31874878e-14,
#        2.31874878e-14, 2.31874878e-14, 2.31874878e-14, 2.31874878e-14,
#        2.31874878e-14, 2.31874878e-14, 2.31874878e-14, 2.31874878e-14,
#        2.31874878e-14, 2.31874878e-14, 2.31874878e-14, 2.31874878e-14,
#        2.31874878e-14, 2.31874878e-14, 2.31874878e-14, 2.31874878e-14,
#        2.31874878e-14, 2.31874878e-14, 1.79898275e-14, 1.00381158e-14,
#        4.60213842e-15])

# %%
VT
# Out:
# array([[-5.55111512e-16, -8.90946178e-03, -1.74176895e-02, ...,
#          1.74176895e-02,  8.90946178e-03,  5.57861103e-16],
#        [-9.99200722e-16, -7.98447192e-03, -1.53325228e-02, ...,
#          1.53325228e-02,  7.98447192e-03,  1.29855366e-15],
#        [ 1.01657769e-01,  5.28097005e-02, -5.44790773e-01, ...,
#         -1.53740796e-03,  4.62714712e-04,  1.26353188e-16],
#        ...,
#        [ 5.17733671e-02, -1.07104198e-01,  1.50913053e-01, ...,
#         -6.77369329e-03, -1.99329054e-03,  1.75454909e-16],
#        [-5.42104580e-02, -1.53616691e-01, -1.29259235e-01, ...,
#         -2.69480500e-03, -6.59764245e-03, -4.32937842e-16],
#        [-1.84507209e-02,  3.82530108e-02, -2.38387872e-01, ...,
#         -1.78952455e-03, -1.64213134e-03, -3.40666864e-16]])

# %%
plt.semilogy(S,'-o')
plt.xlim(0,10)
plt.ylabel('Singular Value', fontsize=18)
plt.xlabel('Index', fontsize=18);

# %%
plt.plot(x,U[:,0])
plt.plot(x,U[:,1])
plt.xlabel('x', fontsize=18)
plt.ylabel('u1(x), u2(x)', fontsize=18)
plt.title('POD modes', fontsize=18);

# %%
plt.plot(t,VT[0,:])
plt.plot(t,VT[1,:])
plt.xlim(0, 4)
plt.xlabel('Time', fontsize=18)
plt.ylabel('a1(t),a2(t)', fontsize=18)
plt.title('Mode coefficients', fontsize=18);

# %%
# Run spectral POD (which here is just a Fourier Transform, as the data is deterministic)
# Note that this requires sufficient resolution in time, and enough snapshots

# Take Fourier transform in time
Yft = np.zeros_like(Y,dtype='complex_')

for j in range(Y.shape[0]):
    Yft[j,:] = np.fft.fft(Y[j,:])
    
freq = np.fft.fftfreq(Nt,d=dt)
plt.contour(x,freq,np.transpose(np.abs(Yft)))
plt.xlabel('x', fontsize=18)
plt.ylabel('frequency (rad/s)', fontsize=18)
plt.title('Spectral content', fontsize=18)
plt.ylim(0,6);

# %%
# Identify indices corresponding to input frequencies
# (we could also find these from the peaks in the above plot if we didn't know these)
ind1 = (np.abs(omega1 - freq)).argmin() 
ind2 = (np.abs(omega2 - freq)).argmin() 
print(freq[ind1])
print(freq[ind2])
plt.plot(x,np.abs(Yft[:,ind1]))
plt.plot(x,np.abs(Yft[:,ind2]))
plt.xlabel('y', fontsize=18)
plt.title('Spectral POD modes');
# Out:
# 1.2987012987012987
# 4.095904095904096

# %%
# Try DMD instead (Note this doesn't work without time delays or complex data)
A = Y[:,1:Nt-1]@linalg.pinv(Y[:,2:Nt])
print(A)
# Out:
# [[ 3.28907241e+00  9.74965204e+06 -2.35995735e+06 ...  4.33442181e+03
#    7.71606219e+03 -2.07914055e+03]
#  [ 3.54727161e+00  1.05145432e+07 -2.54691546e+06 ...  4.90391161e+03
#    8.51104165e+03 -2.43132728e+03]
#  [ 3.82670579e+00  1.13422650e+07 -2.74951913e+06 ...  5.55667205e+03
#    9.40148264e+03 -2.84251424e+03]
#  ...
#  [ 8.67042901e+02  2.57136826e+09 -6.17740265e+08 ...  5.51354746e+05
#    1.54591195e+06 -6.06732925e+04]
#  [ 8.32005006e+02  2.46745721e+09 -5.92776888e+08 ...  5.29074061e+05
#    1.48344042e+06 -5.82214364e+04]
#  [ 7.98161278e+02  2.36708768e+09 -5.68664317e+08 ...  5.07552750e+05
#    1.42309805e+06 -5.58531448e+04]]

# %%
#A = np.dot((ModeCoeffs[1:np.shape(ModeCoeffs)[1],0:r]).T,(la.pinv(ModeCoeffs[0:(np.shape(ModeCoeffs)[1]-1),0:r])).T)

# %%
Lambda, W = np.linalg.eig(A)
LambdaCts = np.log(Lambda[:2])/(dt)

plt.plot(x,np.real(W[:,0]))
plt.plot(x,np.real(W[:,1]))
plt.xlabel('x', fontsize=18)
print(LambdaCts) # incorrect, since we need four independent components to define two frequencies
# Out:
# [787.44062772  +0.j         787.40261685+314.15926536j]
