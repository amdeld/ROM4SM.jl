# %%
using ManifoldLearning, Plots;gr()
# Out:
# Plots.GRBackend()

# %%
X, _ = ManifoldLearning.swiss_roll();

# %%
X
# Out:
# 3×1000 Array{Float64,2}:
#  -9.20343  12.6129   -9.32446   -5.20126  …  -0.906227  12.0068    0.347066
#  20.5316    6.52795  25.2097    16.0914      18.1821     2.90311  17.2214
#   1.33092   1.30474   0.373059   6.79451      7.86732    4.98263  -4.7868

# %%
plot(X,st = :surface, legend=:false)

# %%
M = fit(Isomap, X)
# Out:
# Isomap{ManifoldLearning.BruteForce}(outdim = 2, neighbors = 12)

# %%
 Y = transform(M)
# Out:
# 2×1000 Array{Float64,2}:
#    5.79904  -22.6173    4.65848  11.2843   …  15.4035   -16.2817  30.7077
#  -15.9141    11.8764  -19.0385   -7.47157     -5.64087   17.0401   7.93807

# %%
plot!(Y,legend=:false)
